# %% [markdown]
# # CMU Data Science Club Sustainability Datathon
#
# **Team Name:** andrewID of team member submitting (only 1 member submits for entire team)
#
# **Names:** include member submitting: team member 1, team member 2, team member 3, ...
#
# **Andrew IDs:** include member submitting: andrew id 1, andrew id 2, andrew id 3, ...
#
# **This notebook is only for reference to help your team download the data and get started. Using this notebook is not required.**

# %%
### Load Some Common Packages ###
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We provide two datasets, you may use one or both or none (we encourage you to find your own datasets either entirely or supplementarily!). Refer to the dataset schemas - the column description tables in the instructions packet - to understand what information is contained in the datasets. Additionally, we have provided some guiding questions but feel free to go beyond those.

# %%
### Download the data ###
# !gdown "1Qp3GBd5O4joCNrGc_e8DNimADHCTR56_"
# !gdown --id 1m25KGW8b_BpPYv8mA-YvH-ELg--keDQp
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Qp3GBd5O4joCNrGc_e8DNimADHCTR56_
# To: /content/large_scale_ai_models_added_cols.csv
# 100% 453k/453k [00:00<00:00, 103MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1m25KGW8b_BpPYv8mA-YvH-ELg--keDQp
# To: /content/bloom_emissions.csv
# 100% 1.39M/1.39M [00:00<00:00, 127MB/s]

# %%
### Load the data ###
df_1 = pd.read_csv("large_scale_ai_models_added_cols.csv")
df_1.head()
# Out:
#                  System    Domain  \
# 0         Firefly Video     Video
# 1  Meta Movie Gen Video     Video
# 2  Meta Movie Gen Audio     Audio
# 3          Llama 3.2 3B  Language
# 4           Qwen2.5-72B  Language
#
#                                                 Task  \
# 0                                   Video generation
# 1                                   Video generation
# 2                                   Audio generation
# 3  Language modelling/generation,Text summarizati...
# 4                      Language modelling/generation
#
#                                              Authors  \
# 0                                              Adobe
# 1  Adam Polyak, Amit Zohar, Andrew Brown, Andros ...
# 2  Adam Polyak, Amit Zohar, Andrew Brown, Andros ...
# 3                                                NaN
# 4                                                NaN
#
#              Model accessibility  \
# 0         Hosted access (no API)
# 1                     Unreleased
# 2                     Unreleased
# 3  Open weights (restricted use)
# 4    Open weights (unrestricted)
#
#                                                 Link  Citations  \
# 0  https://news.adobe.com/news/2024/10/101424-ado...        NaN
# 1  https://ai.meta.com/static-resource/movie-gen-...        NaN
# 2  https://ai.meta.com/static-resource/movie-gen-...        NaN
# 3  https://ai.meta.com/blog/llama-3-2-connect-202...        NaN
# 4             https://qwenlm.github.io/blog/qwen2.5/        NaN
#
#                                            Reference Publication date  \
# 0  Adobe Launches Firefly Video Model and Enhance...       2024-10-14
# 1       Movie Gen: A Cast of Media Foundation Models       2024-10-04
# 2       Movie Gen: A Cast of Media Foundation Models       2024-10-04
# 3  Llama 3.2: Revolutionizing edge AI and vision ...       2024-09-24
# 4             Qwen2.5: A Party of Foundation Models!       2024-09-19
#
#   Organization  ...  Finetune compute (FLOP) Finetune compute notes  \
# 0        Adobe  ...                      NaN                    NaN
# 1      Meta AI  ...                      NaN                    NaN
# 2      Meta AI  ...                      NaN                    NaN
# 3      Meta AI  ...                      NaN                    NaN
# 4      Alibaba  ...                      NaN                    NaN
#
#    Hardware quantity Training code accessibility Dataset accessibility  \
# 0                NaN                         NaN                   NaN
# 1             6144.0                         NaN                   NaN
# 2              384.0                         NaN                   NaN
# 3                NaN                  Unreleased                   NaN
# 4                NaN                  Unreleased            Unreleased
#
#                                  Accessibility notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  LLAMA 3.2 COMMUNITY LICENSE AGREEMENT\n\nhttps...
# 4  license: allows commercial. weights only\nhttp...
#
#    Organization categorization (from Organization) Training power (Watts)   \
# 0                                         Industry            3.300000e+14
# 1                                         Industry            2.800000e+13
# 2                                         Industry            3.470000e+13
# 3                                         Industry            1.600000e+15
# 4                                         Industry            1.210000e+14
#
#    Training energy (kWh)  Carbon Emissions from training (lb)
# 0                     NaN                                 NaN
# 1            9.268000e+12                        7.970480e+12
# 2            1.248048e+13                        1.073321e+13
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
# [5 rows x 33 columns]

# %%
df_2 = pd.read_csv("bloom_emissions.csv")
df_2.head()
# Out:
#              timestamp                               project_name  \
# 0  2022-05-18T12:03:49  distilbert-base-uncased_random_wikitext_4
# 1  2022-05-18T12:03:49  distilbert-base-uncased_random_wikitext_4
# 2  2022-05-18T12:03:49  distilbert-base-uncased_random_wikitext_4
# 3  2022-05-18T12:03:49  distilbert-base-uncased_random_wikitext_4
# 4  2022-05-18T12:03:49  distilbert-base-uncased_random_wikitext_4
#
#                                  run_id  duration  emissions  emissions_rate  \
# 0  3d0c0253-711f-482e-b2fa-cf009acb467c  0.912916   0.000027        0.029840
# 1  3d0c0253-711f-482e-b2fa-cf009acb467c  1.000802   0.000029        0.029172
# 2  3d0c0253-711f-482e-b2fa-cf009acb467c  1.062332   0.000030        0.028206
# 3  3d0c0253-711f-482e-b2fa-cf009acb467c  1.110190   0.000031        0.027648
# 4  3d0c0253-711f-482e-b2fa-cf009acb467c  1.157329   0.000031        0.027152
#
#    cpu_power  gpu_power  ram_power  cpu_energy  ...  python_version  \
# 0        0.0    418.779  70.345768         0.0  ...          3.8.10
# 1        0.0    418.763  70.345768         0.0  ...          3.8.10
# 2        0.0    421.098  70.345768         0.0  ...          3.8.10
# 3        0.0    421.098  70.345768         0.0  ...          3.8.10
# 4        0.0    425.624  70.345768         0.0  ...          3.8.10
#
#    cpu_count                                   cpu_model gpu_count  \
# 0       40.0  Intel(R) Xeon(R) Silver 4210 CPU @ 2.20GHz       8.0
# 1       40.0  Intel(R) Xeon(R) Silver 4210 CPU @ 2.20GHz       8.0
# 2       40.0  Intel(R) Xeon(R) Silver 4210 CPU @ 2.20GHz       8.0
# 3       40.0  Intel(R) Xeon(R) Silver 4210 CPU @ 2.20GHz       8.0
# 4       40.0  Intel(R) Xeon(R) Silver 4210 CPU @ 2.20GHz       8.0
#
#                      gpu_model longitude  latitude  ram_total_size  \
# 0  8 x NVIDIA GeForce RTX 3090  -72.9302   41.3186      187.588715
# 1  8 x NVIDIA GeForce RTX 3090  -72.9302   41.3186      187.588715
# 2  8 x NVIDIA GeForce RTX 3090  -72.9302   41.3186      187.588715
# 3  8 x NVIDIA GeForce RTX 3090  -72.9302   41.3186      187.588715
# 4  8 x NVIDIA GeForce RTX 3090  -72.9302   41.3186      187.588715
#
#   tracking_mode on_cloud
# 0       machine        N
# 1       machine        N
# 2       machine        N
# 3       machine        N
# 4       machine        N
#
# [5 rows x 29 columns]

# %%
print(f"Columns of Dataset 1: {df_1.columns}")
print(f"Columns of Dataset 2: {df_2.columns}")
# Out:
# Columns of Dataset 1: Index(['System', 'Domain', 'Task', 'Authors', 'Model accessibility', 'Link',
#        'Citations', 'Reference', 'Publication date', 'Organization',
#        'Parameters', 'Parameters notes', 'Training compute (FLOP)',
#        'Training compute notes', 'Training dataset', 'Training dataset notes',
#        'Training dataset size (datapoints)', 'Dataset size notes',
#        'Training time (hours)', 'Training hardware', 'Abstract',
#        'Country (from Organization)', 'Base model', 'Finetune compute (FLOP)',
#        'Finetune compute notes', 'Hardware quantity',
#        'Training code accessibility', 'Dataset accessibility',
#        'Accessibility notes',
#        'Organization categorization (from Organization)',
#        'Training power (Watts) ', 'Training energy (kWh) ',
#        'Carbon Emissions from training (lb)'],
#       dtype='object')
# Columns of Dataset 2: Index(['timestamp', 'project_name', 'run_id', 'duration', 'emissions',
#        'emissions_rate', 'cpu_power', 'gpu_power', 'ram_power', 'cpu_energy',
#        'gpu_energy', 'ram_energy', 'energy_consumed', 'country_name',
#        'country_iso_code', 'region', 'cloud_provider', 'cloud_region', 'os',
#        'python_version', 'cpu_count', 'cpu_model', 'gpu_count', 'gpu_model',
#        'longitude', 'latitude', 'ram_total_size', 'tracking_mode', 'on_cloud'],
#       dtype='object')

# %%
### Preprocess the data and/or Feature Engineer ###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, how did your team handle missing (Null/NaN) values? Which columns did you feel are most relevant and why?

# %%
### Perform EDA ###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, what did you learn from you EDA? Is the data skewed? If so, how did you handle that?

# %%
### Fit Model(s) ###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, what kind of model did you use? Why did you feel this approach was the best for this task?

# %%
### Model Justification###

# %% [markdown]
# Write some explanations for what your team did in this section. For instance, what kind of analysis justifies your team's use of your team's model? How did your model perform?

# %%
### Make and Interpret Predictions ###

# %% [markdown]
# Write some explanations for what your team did in this section. What did you learn from your predictions? What does this imply about AI in 10 years? 20 years? Do present trends suggest AI is a sustainable venture in the future? How does this tie into the finance industry and how are your hypotheses supported?
